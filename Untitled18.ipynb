# %% [markdown]
# <a href="https://colab.research.google.com/github/kushall07/d-g-l-g/blob/master/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("mg kushal and kaushlesh")
# Out:
# mg kushal and kaushlesh
